# %%
# !pip install pandas


import pandas as pd

# Specify the path to your CSV file
csv_file_path = 'team_stats_2003_2023.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

df.head()
# Out:
# ...
#    year                  team  wins  losses  win_loss_perc  points  \
# 0  2003  New England Patriots    14       2          0.875     348
# 1  2003        Miami Dolphins    10       6          0.625     311
# 2  2003         Buffalo Bills     6      10          0.375     243
# 3  2003         New York Jets     6      10          0.375     283
# 4  2003      Baltimore Ravens    10       6          0.625     391
#
#    points_opp  points_diff  mov   g  ...  rush_td  rush_yds_per_att  rush_fd  \
# 0         238          110  6.9  16  ...        9               3.4       91
# 1         261           50  3.1  16  ...       14               3.7       99
# 2         279          -36 -2.3  16  ...       13               3.9       96
# 3         299          -16 -1.0  16  ...        8               4.0       78
# 4         281          110  6.9  16  ...       18               4.8      115
#
#    penalties  penalties_yds  pen_fd  score_pct  turnover_pct  exp_pts_tot  \
# ...

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 672 entries, 0 to 671
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  672 non-null    int64
#  1   team                  672 non-null    object
#  2   wins                  672 non-null    int64
#  3   losses                672 non-null    int64
#  4   win_loss_perc         672 non-null    float64
#  5   points                672 non-null    int64
#  6   points_opp            672 non-null    int64
#  7   points_diff           672 non-null    int64
#  8   mov                   352 non-null    float64
#  9   g                     672 non-null    int64
#  10  total_yards           672 non-null    int64
#  11  plays_offense         672 non-null    int64
#  12  yds_per_play_offense  672 non-null    float64
#  13  turnovers             672 non-null    int64
#  14  fumbles_lost          672 non-null    int64
# ...

# %%
df.columns = df.columns.str.strip()
selected_columns = ['team', 'pass_att', 'wins', 'win_loss_perc']
df = df[selected_columns]

print(df)
print(df[['team', 'pass_att', 'wins', 'win_loss_perc']].head())
# Out:
#                      team  pass_att  wins  win_loss_perc
# 0    New England Patriots       537    14          0.875
# 1          Miami Dolphins       450    10          0.625
# 2           Buffalo Bills       502     6          0.375
# 3           New York Jets       496     6          0.375
# 4        Baltimore Ravens       415    10          0.625
# ..                    ...       ...   ...            ...
# 667     Carolina Panthers       586     2          0.118
# 668   San Francisco 49ers       491    12          0.706
# 669      Los Angeles Rams       583    10          0.588
# 670      Seattle Seahawks       575     9          0.529
# 671     Arizona Cardinals       555     4          0.235
#
# [672 rows x 4 columns]
#                    team  pass_att  wins  win_loss_perc
# 0  New England Patriots       537    14          0.875
# 1        Miami Dolphins       450    10          0.625
# 2         Buffalo Bills       502     6          0.375
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.scatterplot(x='pass_att', y='wins', data=df)
plt.title('Scatter Plot of Pass Attempts vs Wins')
plt.xlabel('Pass Attempts')
plt.ylabel('Wins')
plt.show()

# %%
plt.figure(figsize=(12, 8))

plt.subplot(2, 2, 1)
sns.histplot(df['pass_att'], kde=True)
plt.title('Distribution of Pass Attempts')

plt.subplot(2, 2, 2)
sns.histplot(df['wins'], kde=True)
plt.title('Distribution of Wins')

plt.subplot(2, 2, 3)
sns.histplot(df['win_loss_perc'], kde=True)
plt.title('Distribution of Win-Loss Percentage')

plt.tight_layout()
plt.show()
